# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/Sonar.csv")
df.sample(5)
# Out:
#          V1      V2      V3      V4      V5      V6      V7      V8      V9  \
# 22   0.0099  0.0484  0.0299  0.0297  0.0652  0.1077  0.2363  0.2385  0.0075
# 164  0.0163  0.0198  0.0202  0.0386  0.0752  0.1444  0.1487  0.1484  0.2442
# 45   0.0408  0.0653  0.0397  0.0604  0.0496  0.1817  0.1178  0.1024  0.0583
# 166  0.0411  0.0277  0.0604  0.0525  0.0489  0.0385  0.0611  0.1117  0.1237
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#         V10  ...     V52     V53     V54     V55     V56     V57     V58  \
# 22   0.1882  ...  0.0173  0.0149  0.0115  0.0202  0.0139  0.0029  0.0160
# 164  0.2822  ...  0.0077  0.0026  0.0031  0.0083  0.0020  0.0084  0.0108
# 45   0.2176  ...  0.0062  0.0129  0.0184  0.0069  0.0198  0.0199  0.0102
# 166  0.2300  ...  0.0217  0.0038  0.0019  0.0065  0.0132  0.0108  0.0050
# 207  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#         V59     V60  Class
# 22   0.0106  0.0134      1
# ...

# %%
df.shape
# Out:
# (208, 61)

# %% [markdown]
# we have 208 rows and 61 coloumn including the target variable

# %%
df
# Out:
#          V1      V2      V3      V4      V5      V6      V7      V8      V9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.describe()
# Out:
#                V1          V2          V3          V4          V5          V6  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                V7          V8          V9         V10  ...         V52  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.013420
# ...

# %%
pd.set_option('display.max_column',500)

# %%
df.isnull()
# Out:
#         V1     V2     V3     V4     V5     V6     V7     V8     V9    V10  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 203  False  False  False  False  False  False  False  False  False  False
# 204  False  False  False  False  False  False  False  False  False  False
# 205  False  False  False  False  False  False  False  False  False  False
# 206  False  False  False  False  False  False  False  False  False  False
# 207  False  False  False  False  False  False  False  False  False  False
#
#        V11    V12    V13    V14    V15    V16    V17    V18    V19    V20  \
# ...

# %%
df.isnull().sum().sum()   #checcking for null values numerically
# Out:
# 0

# %% [markdown]
# # Target Variable

# %%
df['Class'].hist(grid=False)
plt.title('Rock VS Mine')
plt.show()

# %%
df['Class'].value_counts()
# Out:
# 0    111
# 1     97
# Name: Class, dtype: int64

# %% [markdown]
# there is no sign of class imbalance

# %% [markdown]
# # Checking correlation

# %%
df.corr()
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# V1     1.000000  0.735896  0.571537  0.491438  0.344797  0.238921  0.260815
# V2     0.735896  1.000000  0.779916  0.606684  0.419669  0.332329  0.279040
# V3     0.571537  0.779916  1.000000  0.781786  0.546141  0.346275  0.190434
# V4     0.491438  0.606684  0.781786  1.000000  0.726943  0.352805  0.246440
# V5     0.344797  0.419669  0.546141  0.726943  1.000000  0.597053  0.335422
# ...         ...       ...       ...       ...       ...       ...       ...
# V57    0.313725  0.280341  0.380819  0.340254  0.219395  0.161333  0.186324
# V58    0.368132  0.353042  0.334108  0.344865  0.238793  0.203986  0.242646
# V59    0.357116  0.352200  0.425047  0.420266  0.290982  0.220573  0.183578
# V60    0.347078  0.358761  0.373948  0.400626  0.253710  0.178158  0.222493
# Class -0.271694 -0.231238 -0.192195 -0.250638 -0.222232 -0.132327 -0.114748
#
# ...

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f', cmap = 'BuPu')
plt.show()

# %% [markdown]
# unable to identify correlation due to number of column, so findin the correlaton value of independent variable with target variable

# %%
corr_matrix=df.corr()
corr_matrix
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# V1     1.000000  0.735896  0.571537  0.491438  0.344797  0.238921  0.260815
# V2     0.735896  1.000000  0.779916  0.606684  0.419669  0.332329  0.279040
# V3     0.571537  0.779916  1.000000  0.781786  0.546141  0.346275  0.190434
# V4     0.491438  0.606684  0.781786  1.000000  0.726943  0.352805  0.246440
# V5     0.344797  0.419669  0.546141  0.726943  1.000000  0.597053  0.335422
# ...         ...       ...       ...       ...       ...       ...       ...
# V57    0.313725  0.280341  0.380819  0.340254  0.219395  0.161333  0.186324
# V58    0.368132  0.353042  0.334108  0.344865  0.238793  0.203986  0.242646
# V59    0.357116  0.352200  0.425047  0.420266  0.290982  0.220573  0.183578
# V60    0.347078  0.358761  0.373948  0.400626  0.253710  0.178158  0.222493
# Class -0.271694 -0.231238 -0.192195 -0.250638 -0.222232 -0.132327 -0.114748
#
# ...

# %%
type(corr_matrix)
# Out:
# pandas.core.frame.DataFrame

# %%
corr_matrix=df.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class    1.000000
# V36      0.269151
# V35      0.227670
# V37      0.209055
# V34      0.172010
#            ...
# V45     -0.339406
# V10     -0.341142
# V49     -0.351312
# V12     -0.392245
# V11     -0.432855
# Name: Class, Length: 61, dtype: float64

# %% [markdown]
# # checking data distribution

# %%
df.plot(kind='density', subplots=True, layout=(6,11), sharex=False, legend=True, fontsize=1, figsize=(18,12) )
plt.show()

# %% [markdown]
# multiple column have skewness

# %% [markdown]
# # Splitting independent variable and target variable into x and y axis

# %%
x= df.drop("Class", axis=1)
y= df["Class"]

# %%
x
# Out:
#          V1      V2      V3      V4      V5      V6      V7      V8      V9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 203    0
# 204    0
# 205    0
# 206    0
# 207    0
# Name: Class, Length: 208, dtype: int64

# %%
# checking skewness
x.skew().sort_values(ascending=False)
# Out:
# V4     3.401697
# V60    2.775754
# V51    2.716060
# V3     2.652518
# V2     2.155644
# V1     2.131088
# V58    2.098330
# V52    2.093976
# V5     2.018141
# V47    1.790155
# V55    1.789946
# V56    1.780805
# V50    1.761714
# V59    1.737506
# V46    1.706674
# V57    1.653090
# V9     1.633870
# V8     1.481107
# V45    1.366839
# V10    1.281258
# V48    1.277722
# V49    1.273385
# V6     1.248166
# V44    1.235086
# V54    1.093090
# V53    1.060572
# V38    1.033366
# V14    1.022369
# V11    0.987813
# V7     0.970820
# V43    0.909317
# V39    0.908835
# V41    0.863526
# V40    0.861280
# V42    0.860110
# V15    0.763964
# V13    0.736584
# V16    0.694671
# V37    0.676994
# V17    0.654480
# V36    0.619868
# V35    0.591654
# V12    0.588681
# V34    0.563296
# V18    0.525845
# V33    0.423864
# V32    0.313420
# V19    0.283182
# V31    0.259797
# V20   -0.085331
# V30   -0.132390
# V21   -0.252741
# V22   -0.392289
# V29   -0.442007
# V23   -0.594350
# ...

# %% [markdown]
# skewness can be seen in most of the columns so removing the skewness using power_transform function

# %%
from sklearn.preprocessing import power_transform
x_new= power_transform(x)

# %%
x_new
# Out:
# array([[-0.27559197,  0.27040028,  0.29141926, ...,  0.40035038,
#          0.50276068, -0.77673576],
#        [ 1.09332037,  0.80162153,  1.34753955, ..., -0.3971726 ,
#         -0.3372011 , -0.33482801],
#        [ 0.16435246,  0.96785776,  1.7063881 , ...,  1.45541497,
#          0.59178889,  0.61276412],
#        ...,
#        [ 1.31612574,  0.52119085, -0.83388303, ...,  1.19851347,
#          0.2498297 , -0.81661951],
#        [ 0.41211554,  0.19596508,  0.50237865, ...,  0.30261849,
#         -0.79598579, -0.20155368],
#        [ 0.15144333,  0.23765441, -1.09243326, ..., -0.77133983,
#         -0.10911474,  1.27854891]])

# %%
# checking skewness
pd.DataFrame(x_new).skew().sort_values(ascending=False)
# Out:
# 57    0.220689
# 59    0.204745
# 0     0.200661
# 56    0.200251
# 1     0.196446
# 3     0.190002
# 54    0.189057
# 2     0.187103
# 44    0.170784
# 45    0.169289
# 58    0.166418
# 51    0.148282
# 4     0.140451
# 48    0.132635
# 52    0.130364
# 53    0.125757
# 16    0.124196
# 46    0.120549
# 55    0.120513
# 49    0.106623
# 15    0.102740
# 36    0.100569
# 47    0.096302
# 17    0.094088
# 35    0.087954
# 37    0.086653
# 43    0.083057
# 38    0.078671
# 34    0.078044
# 8     0.077245
# 50    0.077191
# 9     0.073024
# 14    0.070344
# 40    0.061931
# 41    0.049309
# 33    0.047734
# 10    0.047685
# 7     0.039388
# 13    0.039062
# 5     0.038764
# 39    0.035032
# 11    0.033161
# 42    0.032043
# 12    0.024720
# 32    0.020193
# 18    0.019011
# 6     0.017842
# 31    0.005106
# 30   -0.001851
# 29   -0.047004
# 19   -0.074176
# 20   -0.106673
# 28   -0.133525
# 21   -0.144238
# 23   -0.163443
# 27   -0.167409
# 22   -0.180086
# 26   -0.195002
# ...

# %%
x.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
#        'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41',
#        'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50', 'V51',
#        'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60'],
#       dtype='object')

# %%
x=pd.DataFrame(x_new, columns= x.columns)

# %%
x.skew().sort_values(ascending=False) # validating that skewness has been removed or not
# Out:
# V58    0.220689
# V60    0.204745
# V1     0.200661
# V57    0.200251
# V2     0.196446
# V4     0.190002
# V55    0.189057
# V3     0.187103
# V45    0.170784
# V46    0.169289
# V59    0.166418
# V52    0.148282
# V5     0.140451
# V49    0.132635
# V53    0.130364
# V54    0.125757
# V17    0.124196
# V47    0.120549
# V56    0.120513
# V50    0.106623
# V16    0.102740
# V37    0.100569
# V48    0.096302
# V18    0.094088
# V36    0.087954
# V38    0.086653
# V44    0.083057
# V39    0.078671
# V35    0.078044
# V9     0.077245
# V51    0.077191
# V10    0.073024
# V15    0.070344
# V41    0.061931
# V42    0.049309
# V34    0.047734
# V11    0.047685
# V8     0.039388
# V14    0.039062
# V6     0.038764
# V40    0.035032
# V12    0.033161
# V43    0.032043
# V13    0.024720
# V33    0.020193
# V19    0.019011
# V7     0.017842
# V32    0.005106
# V31   -0.001851
# V30   -0.047004
# V20   -0.074176
# V21   -0.106673
# V29   -0.133525
# V22   -0.144238
# V24   -0.163443
# ...

# %%
sk= x.skew()

# %%
sk
# Out:
# V1     0.200661
# V2     0.196446
# V3     0.187103
# V4     0.190002
# V5     0.140451
# V6     0.038764
# V7     0.017842
# V8     0.039388
# V9     0.077245
# V10    0.073024
# V11    0.047685
# V12    0.033161
# V13    0.024720
# V14    0.039062
# V15    0.070344
# V16    0.102740
# V17    0.124196
# V18    0.094088
# V19    0.019011
# V20   -0.074176
# V21   -0.106673
# V22   -0.144238
# V23   -0.180086
# V24   -0.163443
# V25   -0.205760
# V26   -0.202206
# V27   -0.195002
# V28   -0.167409
# V29   -0.133525
# V30   -0.047004
# V31   -0.001851
# V32    0.005106
# V33    0.020193
# V34    0.047734
# V35    0.078044
# V36    0.087954
# V37    0.100569
# V38    0.086653
# V39    0.078671
# V40    0.035032
# V41    0.061931
# V42    0.049309
# V43    0.032043
# V44    0.083057
# V45    0.170784
# V46    0.169289
# V47    0.120549
# V48    0.096302
# V49    0.132635
# V50    0.106623
# V51    0.077191
# V52    0.148282
# V53    0.130364
# V54    0.125757
# V55    0.189057
# ...

# %%
np.abs(3)
# Out:
# 3

# %%
np.abs(-3) #multiply the no. with -1
# Out:
# 3

# %%
sk[np.abs(sk)>0.5]
# Out:
# Series([], dtype: float64)

# %%
x.skew()[np.abs(x.skew())<0.25].all()
# Out:
# True

# %% [markdown]
# skewness has been removed

# %% [markdown]
# # Checking Outliers

# %% [markdown]
# There are 61 columns so ploting columns together and in 2 steps

# %%
#plotting box plot for first 30 columns
x.iloc[:,0:30].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#plotting for all the columns
x.iloc[:,30:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# one or two outliersfor 3 columns that are close to whiskers so those are not outliers

# %% [markdown]
#  # quantifying it

# %%
from scipy.stats import zscore
(np.abs(zscore(x))<3).all()
# Out:
# V1     True
# V2     True
# V3     True
# V4     True
# V5     True
# V6     True
# V7     True
# V8     True
# V9     True
# V10    True
# V11    True
# V12    True
# V13    True
# V14    True
# V15    True
# V16    True
# V17    True
# V18    True
# V19    True
# V20    True
# V21    True
# V22    True
# V23    True
# V24    True
# V25    True
# V26    True
# V27    True
# V28    True
# V29    True
# V30    True
# V31    True
# V32    True
# V33    True
# V34    True
# V35    True
# V36    True
# V37    True
# V38    True
# V39    True
# V40    True
# V41    True
# V42    True
# V43    True
# V44    True
# V45    True
# V46    True
# V47    True
# V48    True
# V49    True
# V50    True
# V51    True
# V52    True
# V53    True
# V54    True
# V55    True
# V56    True
# V57    True
# V58    True
# V59    True
# V60    True
# dtype: bool

# %% [markdown]
# # Training process begins

# %% [markdown]
# finding best random state

# %%
# TRAINING ===> Bias created ===> selection bias

# %%
#10 observation(5-Rock, 5-Mine) ===> 6 training(4 mine , 1 rock)(imbalance -- 4:1 or 80:20)
#4- testing( 5 - mine)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Best random state

# %%
maxAccu=0 # maximum accuracy
maxRS =0 #best random state for which maximum accuracy is achieved

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=20, random_state =i)
    LR = LogisticRegression()
    LR.fit(x_train, y_train)  # fitting the data trains the model
    predrf = LR.predict(x_test)  #this is the predicted target variable
    acc = accuracy_score(y_test, predrf)  # accuracy score
    print('accuracy_score', acc, 'random_state',i)
    
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
        print('accuracy', maxAccu, 'random_state',i)
# Out:
# accuracy_score 0.7 random_state 1
# accuracy 0.7 random_state 1
# accuracy_score 0.85 random_state 2
# accuracy 0.85 random_state 2
# accuracy_score 0.7 random_state 3
# accuracy_score 0.75 random_state 4
# accuracy_score 0.8 random_state 5
# accuracy_score 0.7 random_state 6
# accuracy_score 0.55 random_state 7
# accuracy_score 0.8 random_state 8
# accuracy_score 0.8 random_state 9
# accuracy_score 0.85 random_state 10
# accuracy_score 0.75 random_state 11
# accuracy_score 0.8 random_state 12
# accuracy_score 0.8 random_state 13
# accuracy_score 0.85 random_state 14
# accuracy_score 0.75 random_state 15
# accuracy_score 0.7 random_state 16
# accuracy_score 0.85 random_state 17
# accuracy_score 0.75 random_state 18
# accuracy_score 0.85 random_state 19
# accuracy_score 0.75 random_state 20
# accuracy_score 0.7 random_state 21
# accuracy_score 0.85 random_state 22
# accuracy_score 0.7 random_state 23
# accuracy_score 0.85 random_state 24
# accuracy_score 0.85 random_state 25
# ...

# %%
print('Best accuracy is',maxAccu, 'on Random state',maxRS)
# Out:
# Best accuracy is 1.0 on Random state 140

# %% [markdown]
# # Ceating Train_test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .20, random_state = 140)

# %%
x_train
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 204  0.522051 -1.194353 -0.235241  0.403843  0.295163  0.022315 -0.261079
# 200 -0.876424  0.334316 -0.098189 -1.707729  0.207868  0.692951  0.793022
# 167 -0.818872 -0.053887 -1.217078 -1.682946 -1.220068 -1.768575 -1.940083
# 132  2.031725  1.473422  0.898657  0.527823 -0.043034  0.477091 -0.351485
# 5    0.313183  0.577108 -0.332567 -1.154405 -0.715843  0.085019  0.127045
# ..        ...       ...       ...       ...       ...       ...       ...
# 80  -0.059241  0.262264 -1.735208 -0.234751 -0.492896  0.858220  1.509456
# 150 -0.206346 -0.145373 -1.223432  0.023649 -0.578802 -0.383374  0.546592
# 151 -0.045028  0.029561 -0.890818 -0.888018 -0.632227 -2.230932 -2.102148
# 166  0.932955 -0.150288  0.834382  0.286787 -0.391972 -1.363669 -1.075796
# 104  0.434649  0.801622  0.957755  0.274383 -0.058359 -0.837594 -0.949424
#
#            V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
x_test
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 197  0.736689  0.463437  0.546865 -0.772239 -0.097099 -1.771789 -0.323740
# 147  1.632368  1.134390  1.146061  1.517898  2.104969  0.559828  1.023746
# 202  0.227712  0.298619  0.495932  1.076605  0.966036  0.296135  0.375286
# 207  0.151443  0.237654 -1.092433 -0.669872 -1.324366 -1.503542 -0.972550
# 114 -1.045505 -0.436757 -0.370633 -0.199940  1.095918  1.587038  0.593627
# 23  -1.035307 -0.864470 -1.092433 -1.720179 -1.336146  0.213940 -0.197545
# 96  -0.428322 -0.890156 -1.838905 -1.335173 -0.597547 -1.113832 -1.711713
# 161  0.423417  0.237654 -0.647945 -0.883107 -0.489875 -0.618814 -0.361444
# 183 -1.234663  0.399988  1.025918  0.733117  0.556231 -0.029622 -0.329668
# 186 -0.206346 -0.613126  0.229361 -0.454154  0.154703  1.033558  0.515858
# 196 -1.769792 -1.844767 -0.365844  0.041060  0.688021 -0.242302 -0.483007
# 59  -0.935071 -0.851707 -0.626823 -1.149073 -0.788441 -0.544824 -0.495375
# ...

# %%
y_train
# Out:
# 204    0
# 200    0
# 167    0
# 132    0
# 5      1
#       ..
# 80     1
# 150    0
# 151    0
# 166    0
# 104    0
# Name: Class, Length: 166, dtype: int64

# %%
y_test
# Out:
# 197    0
# 147    0
# 202    0
# 207    0
# 114    0
# 23     1
# 96     1
# 161    0
# 183    0
# 186    0
# 196    0
# 59     1
# 136    0
# 110    0
# 130    0
# 58     1
# 30     1
# 142    0
# 32     1
# 49     1
# 184    0
# 81     1
# 108    0
# 14     1
# 121    0
# 21     1
# 73     1
# 45     1
# 100    0
# 51     1
# 181    0
# 152    0
# 128    0
# 171    0
# 61     1
# 177    0
# 37     1
# 11     1
# 71     1
# 120    0
# 201    0
# 16     1
# Name: Class, dtype: int64

# %%
x_train.shape
# Out:
# (166, 60)

# %%
y_train.shape
# Out:
# (166,)

# %%
x_test.shape
# Out:
# (42, 60)

# %%
y_test.shape
# Out:
# (42,)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

LR = LogisticRegression()
LR.fit(x_train, y_train)
predlr = LR.predict(x_test)
print('Accuracy',accuracy_score(y_test,predlr)*100)
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# Accuracy 88.09523809523809
# [[22  2]
#  [ 3 15]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        24
#            1       0.88      0.83      0.86        18
#
#     accuracy                           0.88        42
#    macro avg       0.88      0.88      0.88        42
# weighted avg       0.88      0.88      0.88        42

# %% [markdown]
# #  Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
preddt = dt.predict(x_test)
print('Accuracy',accuracy_score(y_test,preddt)*100)
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# Accuracy 80.95238095238095
# [[21  3]
#  [ 5 13]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84        24
#            1       0.81      0.72      0.76        18
#
#     accuracy                           0.81        42
#    macro avg       0.81      0.80      0.80        42
# weighted avg       0.81      0.81      0.81        42

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
pred = svc.predict(x_test)
print('Accuracy',accuracy_score(y_test,pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# Accuracy 92.85714285714286
# [[24  0]
#  [ 3 15]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        24
#            1       1.00      0.83      0.91        18
#
#     accuracy                           0.93        42
#    macro avg       0.94      0.92      0.93        42
# weighted avg       0.94      0.93      0.93        42

# %% [markdown]
# # Random Forest Clssifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(x_train, y_train)
predrf = rf.predict(x_test)
print('Accuracy',accuracy_score(y_test,predrf)*100)
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# Accuracy 92.85714285714286
# [[24  0]
#  [ 3 15]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        24
#            1       1.00      0.83      0.91        18
#
#     accuracy                           0.93        42
#    macro avg       0.94      0.92      0.93        42
# weighted avg       0.94      0.93      0.93        42

# %% [markdown]
# logistic regression,Random forestand svc are producing good accuracy. Checking cross validation score for overfitting(if exist)

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

scr= cross_val_score(LR, x, y, cv=7)
print('cross validation score of Logistic Regression:',scr.mean())
# Out:
# cross validation score of Logistic Regression: 0.6546798029556651

# %%
scr
# Out:
# array([0.33333333, 0.53333333, 0.73333333, 0.66666667, 0.83333333,
#        0.68965517, 0.79310345])

# %%
from sklearn.model_selection import cross_val_score

scr_9= cross_val_score(LR, x, y, cv=9)
print('cross validation score of Logistic Regression:', scr_9.mean())
# Out:
# cross validation score of Logistic Regression: 0.7230273752012882

# %%
from sklearn.model_selection import cross_val_score

scr2= cross_val_score(rf, x, y, cv=5)
print('cross validation score of Random forest:', scr2.mean())
# Out:
# cross validation score of Random forest: 0.6926829268292682

# %%
from sklearn.model_selection import cross_val_score

scr3= cross_val_score(svc, x, y, cv=5)
print('cross validation score of SVC :', scr3.mean())
# Out:
# cross validation score of SVC : 0.6492450638792102

# %% [markdown]
# Random Forest is performing better than all

# %% [markdown]
# # Hyperpara meter tuning

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list
parameters ={'max_features':['auto','sqrt','log2'],
           'max_depth':[4,5,6,7,8],
           'criterion':['gini', 'entropy']}

# %%
GCV= GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
GCV.fit(x_train,y_train) #fitting the data 
GCV.best_params_  # Printing the best parameter found by GridSearchCV
# Out:
# {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2'}

# %%
type(GCV)
# Out:
# sklearn.model_selection._search.GridSearchCV

# %%
GCV.best_estimator_
# Out:
# RandomForestClassifier(max_depth=7, max_features='log2')

# %%
GCV_pred= GCV.best_estimator_.predict(x_test)  #predict with best parameter
accuracy_score(y_test,GCV_pred) # checking final accuracy
# Out:
# 0.9047619047619048

# %% [markdown]
# # ROC AUC plot

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title("ROC AUC_plot")
plt.show()

# %% [markdown]
# # Model Saving

# %%
import pickle
filename = 'inhouse_Sonar.pkl'
pickle.dump(GCV, open(filename, 'wb'))
